# %% [markdown]
# # CHATBOTS - Using Natural Language Processing and Tensorflow

# %%
#Used in Tensorflow Model
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import tflearn
import random

#Usde to for Contextualisation and Other NLP Tasks.
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()

#Other
import json
import pickle
import warnings
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From c:\Users\psund\anaconda3\envs\qwerty\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)

# %%
import nltk
from nltk.stem import SnowballStemmer
nltk.download(['stopwords'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     c:\Users\psund\anaconda3\envs\qwerty\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print("Processing the Intents.....")
with open('intents.json') as json_data:
    intents = json.load(json_data)
# Out:
# Processing the Intents.....

# %%
words = []
classes = []
documents = []
ignore_words = ['?', '_', '!', '-']
print("Looping through the Intents to Convert them to words, classes, documents and ignore_words.......")
for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word in the sentence
        w = nltk.word_tokenize(pattern)
        # add to our words list
        words.extend(w)
        # add to documents in our corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# Looping through the Intents to Convert them to words, classes, documents and ignore_words.......

# %%
print("Stemming, Lowering and Removing Duplicates.......")
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# remove duplicates
classes = sorted(list(set(classes)))

print (len(documents), "documents")
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
# Out:
# Stemming, Lowering and Removing Duplicates.......
# 223 documents
# 75 classes ['academic_advising', 'academics_majors', 'academics_reputation', 'accessibility', 'admission', 'alumni_association', 'campus_diversity', 'campus_facilities', 'campus_navigation', 'campus_wifi', 'career_services', 'class_format', 'class_size', 'co-op_program', 'collaborative_work', 'complaints', 'computer_labs', 'contact', 'courses', 'creator', 'dorm_quality', 'employer_recruitment', 'events', 'facilities', 'farewell', 'favorite_class', 'favorite_place_on_campus', 'fees', 'fellow_students', 'first_choice_classes', 'first_year_experience', 'food', 'fraternities_sororities', 'friendly_students', 'greeting', 'hands-on_experiences', 'happiness', 'hometown_activities', 'hostel', 'hours', 'identity', 'improvements', 'independent_study', 'interactions_among_students', 'international_students', 'internship_opportunities', 'leadership_opportunities', 'library', 'location', 'mentorship_program', 'non_class_activities', 'notable_graduates', 'on_campus_housing', 'placement', 'popular_clubs', 'professor_research', 'professors_office_hours', 'professors_teachers', 'professors_vs_TAs', 'reading_writing', 'school_choice', 'school_spirit', 'service_learning', 'social_scene', 'sports_popularity', 'strengths', 'student_body_unique', 'student_cliques', 'study_abroad', 'study_locations', 'study_time', 'summer_jobs', 'tutoring_programs', 'typical_day', 'weekend_activities']
# 345 unique stemmed words ['#', "'re", "'s", '(', ')', ',', '.', '1', 'a', 'abl', 'about', 'abroad', 'academ', 'access', 'act', 'address', 'admin', 'admit', 'adv', 'aid', 'alumn', 'among', 'an', 'and', 'any', 'anyth', 'apart', 'ar', 'are', 'area', 'around', 'as', 'assign', 'assist', 'assocy', 'at', 'athlet', 'attend', 'attract', 'av', 'avail', 'background', 'be', 'being', 'belong', 'best', 'big', 'body', 'branch', 'build', 'by', 'bye', 'cal', 'camp', 'can', 'capston', 'car', 'cent', 'choos', 'class', 'classroom', 'cliqu', 'club', 'co-op', 'collab', 'colleg', 'comfort', 'commun', 'complaint', 'complex', 'comput', 'connect', 'contact', 'coop', 'could', 'country', 'cours', 'cre', 'criter', 'cross-cultural', 'culmin', 'cult', 'dai', 'day', 'decid', 'depart', 'describ', 'desir', 'develop', 'did', 'diff', 'din', 'discussion-based', 'divers', 'do', 'doe', 'dorm', 'dormit', 'each', 'easy', 'educ', 'effect', 'els', 'embrac', 'emphas', 'employ', 'eng', 'enjoy', 'enough', 'enrol', 'etc', 'ev', 'ex', 'exclud', 'expect', 'expery', 'facil', 'facul', 'fair', 'fam', 'favorit', 'fee', 'fellow', 'field', 'fin', 'find', 'first-choice', 'first-year', 'food', 'for', 'form', 'fratern', 'fre', 'freshm', 'friend', 'from', 'gen', 'get', 'good', 'goodby', 'gradu', 'greek', 'group', 'guid', 'gym', 'had', 'hands-on', 'hang', 'happy', 'hav', 'heavy', 'hello', 'help', 'her', 'hey', 'hi', 'high', 'hold', 'hometown', 'hostel', 'hour', 'hous', 'how', 'i', 'improv', 'in', 'includ', 'independ', 'individ', 'interact', 'intern', 'into', 'involv', 'is', 'issu', 'it', 'job', 'kind', 'lab', 'larg', 'lat', 'layout', 'lead', 'learn', 'lecture-based', 'libr', 'lif', 'lik', 'liv', 'loc', 'lot', 'mad', 'maj', 'mak', 'many', 'me', 'meet', 'ment', 'modern', 'most', 'much', 'nam', 'navig', 'near', 'nee', 'network', 'new', 'not', 'numb', 'of', 'off', 'oft', 'on', 'on-campus', 'one-on-on', 'op', 'opportun', 'opt', 'or', 'org', 'oth', 'out', 'outsid', 'particip', 'peopl', 'per', 'perc', 'plac', 'pop', 'popul', 'posit', 'pot', 'pract', 'prefer', 'pres', 'prid', 'prim', 'process', 'profess', 'program', 'project', 'promot', 'provid', 'qual', 'quiet', 'rac', 'reach', 'read', 'record', 'recr', 'recruit', 'registr', 'rely', 'repres', 'reput', 'requir', 'research', 'resourc', 'routin', 'satisfy', 'scen', 'school', 'sci', 'see', 'segreg', 'select', 'semest', 'sens', 'serv', 'set', 'short', 'should', 'show', 'sign', 'siz', 'skil', 'smal', 'soc', 'som', 'sor', 'sought-after', 'spec', 'spend', 'spirit', 'sport', 'spot', 'staff', 'stand', 'standout', 'strengths', 'strong', 'structured', 'stud', 'student-friendly', 'study', 'subject', 'success', 'sum', 'support', 'tak', 'talk', 'tas', 'taught', 'teach', 'teamwork', 'tel', 'telephon', 'the', 'their', 'them', 'ther', 'they', 'thi', 'thing', 'think', 'through', 'tim', 'to', 'tradit', 'tut', 'typ', 'un', 'upcom', 'us', 'vis', 'was', 'week', 'weekend', 'well-maintained', 'well-regarded', 'wer', 'what', 'when', 'wher', 'which', 'who', 'why', 'wif', 'wil', 'with', 'work', 'would', 'writ', 'yo', 'you']

# %%
import re
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print("Removing unnecessary spaces, special symbols, numbers, and stopwords")
words = [re.sub(r'[^a-zA-Z]', ' ', w).strip() for w in words if w.lower() not in stop_words]
words = sorted(list(set(filter(None, words))))
words = [word for word in words if not any(char.isdigit() for char in word)]
classes = sorted(list(set(classes)))
print(len(words), "words obtained after unnecessary things")
print("words are",words)
print(classes)
print(documents)
# Out:
# Removing unnecessary spaces, special symbols, numbers, and stopwords
# 291 words obtained after unnecessary things
# words are ['abl', 'abroad', 'academ', 'access', 'act', 'address', 'admin', 'admit', 'adv', 'aid', 'alumn', 'among', 'anyth', 'apart', 'ar', 'area', 'around', 'assign', 'assist', 'assocy', 'athlet', 'attend', 'attract', 'av', 'avail', 'background', 'belong', 'best', 'big', 'body', 'branch', 'build', 'bye', 'cal', 'camp', 'capston', 'car', 'cent', 'choos', 'class', 'classroom', 'cliqu', 'club', 'co op', 'collab', 'colleg', 'comfort', 'commun', 'complaint', 'complex', 'comput', 'connect', 'contact', 'coop', 'could', 'country', 'cours', 'cre', 'criter', 'cross cultural', 'culmin', 'cult', 'dai', 'day', 'decid', 'depart', 'describ', 'desir', 'develop', 'diff', 'din', 'discussion based', 'divers', 'doe', 'dorm', 'dormit', 'easy', 'educ', 'effect', 'els', 'embrac', 'emphas', 'employ', 'eng', 'enjoy', 'enough', 'enrol', 'etc', 'ev', 'ex', 'exclud', 'expect', 'expery', 'facil', 'facul', 'fair', 'fam', 'favorit', 'fee', 'fellow', 'field', 'fin', 'find', 'first choice', 'first year', 'food', 'form', 'fratern', 'fre', 'freshm', 'friend', 'gen', 'get', 'good', 'goodby', 'gradu', 'greek', 'group', 'guid', 'gym', 'hands on', 'hang', 'happy', 'hav', 'heavy', 'hello', 'help', 'hey', 'hi', 'high', 'hold', 'hometown', 'hostel', 'hour', 'hous', 'improv', 'includ', 'independ', 'individ', 'interact', 'intern', 'involv', 'issu', 'job', 'kind', 'lab', 'larg', 'lat', 'layout', 'lead', 'learn', 'lecture based', 'libr', 'lif', 'lik', 'liv', 'loc', 'lot', 'mad', 'maj', 'mak', 'many', 'meet', 'ment', 'modern', 'much', 'nam', 'navig', 'near', 'nee', 'network', 'new', 'numb', 'oft', 'on campus', 'one on on', 'op', 'opportun', 'opt', 'org', 'oth', 'outsid', 'particip', 'peopl', 'per', 'perc', 'plac', 'pop', 'popul', 'posit', 'pot', 'pract', 'prefer', 'pres', 'prid', 'prim', 'process', 'profess', 'program', 'project', 'promot', 'provid', 'qual', 'quiet', 'rac', 're', 'reach', 'read', 'record', 'recr', 'recruit', 'registr', 'rely', 'repres', 'reput', 'requir', 'research', 'resourc', 'routin', 's', 'satisfy', 'scen', 'school', 'sci', 'see', 'segreg', 'select', 'semest', 'sens', 'serv', 'set', 'short', 'show', 'sign', 'siz', 'skil', 'smal', 'soc', 'som', 'sor', 'sought after', 'spec', 'spend', 'spirit', 'sport', 'spot', 'staff', 'stand', 'standout', 'strengths', 'strong', 'structured', 'stud', 'student friendly', 'study', 'subject', 'success', 'sum', 'support', 'tak', 'talk', 'tas', 'taught', 'teach', 'teamwork', 'tel', 'telephon', 'ther', 'thi', 'thing', 'think', 'tim', 'tradit', 'tut', 'typ', 'un', 'upcom', 'us', 'vis', 'week', 'weekend', 'well maintained', 'well regarded', 'wer', 'wher', 'wif', 'wil', 'work', 'would', 'writ', 'yo']
# ['academic_advising', 'academics_majors', 'academics_reputation', 'accessibility', 'admission', 'alumni_association', 'campus_diversity', 'campus_facilities', 'campus_navigation', 'campus_wifi', 'career_services', 'class_format', 'class_size', 'co-op_program', 'collaborative_work', 'complaints', 'computer_labs', 'contact', 'courses', 'creator', 'dorm_quality', 'employer_recruitment', 'events', 'facilities', 'farewell', 'favorite_class', 'favorite_place_on_campus', 'fees', 'fellow_students', 'first_choice_classes', 'first_year_experience', 'food', 'fraternities_sororities', 'friendly_students', 'greeting', 'hands-on_experiences', 'happiness', 'hometown_activities', 'hostel', 'hours', 'identity', 'improvements', 'independent_study', 'interactions_among_students', 'international_students', 'internship_opportunities', 'leadership_opportunities', 'library', 'location', 'mentorship_program', 'non_class_activities', 'notable_graduates', 'on_campus_housing', 'placement', 'popular_clubs', 'professor_research', 'professors_office_hours', 'professors_teachers', 'professors_vs_TAs', 'reading_writing', 'school_choice', 'school_spirit', 'service_learning', 'social_scene', 'sports_popularity', 'strengths', 'student_body_unique', 'student_cliques', 'study_abroad', 'study_locations', 'study_time', 'summer_jobs', 'tutoring_programs', 'typical_day', 'weekend_activities']
# [(['Hi'], 'greeting'), (['Hello'], 'greeting'), (['Hey'], 'greeting'), (['Good', 'day'], 'greeting'), (['How', 'are', 'you', '?'], 'greeting'), (['how', 'was', 'your', 'day'], 'greeting'), (['Goodbye'], 'farewell'), (['Bye'], 'farewell'), (['See', 'you', 'later'], 'farewell'), (['Talk', 'to', 'you', 'later'], 'farewell'), (['Who', 'created', 'you', '?'], 'creator'), (['Who', 'is', 'your', 'developer', '?'], 'creator'), (['Who', 'made', 'you', '?'], 'creator'), (['What', 'is', 'your', 'name', '?'], 'identity'), (['What', 'should', 'I', 'call', 'you', '?'], 'identity'), (['Who', 'are', 'you', '?'], 'identity'), (['What', 'are', 'the', 'college', 'timings', '?'], 'hours'), (['When', 'is', 'the', 'college', 'open', '?'], 'hours'), (['What', 'are', 'your', 'hours', 'of', 'operation', '?'], 'hours'), (['How', 'can', 'I', 'contact', 'the', 'college', '?'], 'contact'), (['What', 'is', 'the', 'college', 'telephone', 'number', '?'], 'contact'), (['Can', 'I', 'get', 'your', 'contact', 'number', '?'], 'contact'), (['What', 'courses', 'are', 'offered', 'in', 'the', 'college', '?'], 'courses'), (['Can', 'you', 'tell', 'me', 'about', 'the', 'available', 'courses', '?'], 'courses'), (['What', 'are', 'the', 'branches', 'in', 'the', 'college', '?'], 'courses'), (['How', 'much', 'is', 'the', 'college', 'fee', '?'], 'fees'), (['Tell', 'me', 'about', 'the', 'fees'], 'fees'), (['What', 'are', 'the', 'hostel', 'fees', '?'], 'fees'), (['Where', 'is', 'the', 'college', 'located', '?'], 'location'), (['What', 'is', 'the', 'college', 'address', '?'], 'location'), (['How', 'can', 'I', 'reach', 'the', 'college', '?'], 'location'), (['Does', 'the', 'college', 'provide', 'hostel', 'facilities', '?'], 'hostel'), (['Where', 'is', 'the', 'hostel', 'located', '?'], 'hostel'), (['What', 'are', 'the', 'hostel', 'fees', '?'], 'hostel'), (['What', 'events', 'are', 'organized', 'in', 'the', 'college', '?'], 'events'), (['Are', 'there', 'any', 'upcoming', 'events', '?'], 'events'), (['Tell', 'me', 'about', 'the', 'college', 'events', '.'], 'events'), (['What', 'is', 'the', 'admission', 'process', '?'], 'admission'), (['How', 'can', 'I', 'take', 'admission', 'in', 'the', 'college', '?'], 'admission'), (['Tell', 'me', 'about', 'the', 'admission', 'criteria', '.'], 'admission'), (['Does', 'the', 'college', 'have', 'a', 'library', '?'], 'library'), (['Where', 'is', 'the', 'library', 'located', '?'], 'library'), (['What', 'are', 'the', 'library', 'timings', '?'], 'library'), (['What', 'facilities', 'are', 'available', 'in', 'the', 'college', '?'], 'facilities'), (['Tell', 'me', 'about', 'the', 'college', 'facilities', '.'], 'facilities'), (['Do', 'you', 'have', 'a', 'sports', 'complex', '?'], 'facilities'), (['How', 'are', 'the', 'placements', 'in', 'the', 'college', '?'], 'placement'), (['Tell', 'me', 'about', 'the', 'college', 'placements', '.'], 'placement'), (['What', 'is', 'the', 'placement', 'record', '?'], 'placement'), (['Why', 'did', 'you', 'choose', 'this', 'school', '?'], 'school_choice'), (['What', 'made', 'you', 'decide', 'to', 'attend', 'this', 'college', '?'], 'school_choice'), (['Are', 'you', 'happy', 'here', '?'], 'happiness'), (['Do', 'you', 'enjoy', 'being', 'at', 'this', 'college', '?'], 'happiness'), (['What', 'are', 'your', 'school', "'s", 'strengths', '?'], 'strengths'), (['What', 'makes', 'your', 'college', 'stand', 'out', '?'], 'strengths'), (['What', "'s", 'your', '#', '1', 'complaint', 'about', 'your', 'school', '?'], 'complaints'), (['What', 'do', 'you', 'think', 'needs', 'improvement', 'in', 'your', 'college', '?'], 'complaints'), (['What', 'else', 'could', 'stand', 'to', 'be', 'improved', '?'], 'improvements'), (['In', 'which', 'areas', 'do', 'you', 'think', 'your', 'college', 'can', 'improve', '?'], 'improvements'), (['How', 'accessible', 'are', 'administrators', ',', 'registrars', ',', 'financial', 'aid', 'officers', ',', 'etc', '.', '?'], 'accessibility'), (['Can', 'students', 'easily', 'reach', 'out', 'to', 'college', 'staff', 'when', 'ne ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Your existing code for preprocessing without stemming
ignore_words = ['?', '_', '!', '-']
words = [w.lower() for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

# Assuming 'documents' is a list of strings containing your text data

# Combine all words into a single string
text = " ".join(words)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated word cloud using Matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk import ngrams
from collections import Counter

# %%
#generating bigram
n = 2  
bigrams = ngrams(words, n)
# Count the occurrences of each bigram
bigram_counts = Counter(bigrams)

# Print the bigram frequencies
for bigram, count in bigram_counts.items():
    print(f"{bigram}: {count} times")
# Out:
# ('abl', 'abroad'): 1 times
# ('abroad', 'academ'): 1 times
# ('academ', 'access'): 1 times
# ('access', 'act'): 1 times
# ('act', 'address'): 1 times
# ('address', 'admin'): 1 times
# ('admin', 'admit'): 1 times
# ('admit', 'adv'): 1 times
# ('adv', 'aid'): 1 times
# ('aid', 'alumn'): 1 times
# ('alumn', 'among'): 1 times
# ('among', 'anyth'): 1 times
# ('anyth', 'apart'): 1 times
# ('apart', 'ar'): 1 times
# ('ar', 'area'): 1 times
# ('area', 'around'): 1 times
# ('around', 'assign'): 1 times
# ('assign', 'assist'): 1 times
# ('assist', 'assocy'): 1 times
# ('assocy', 'athlet'): 1 times
# ('athlet', 'attend'): 1 times
# ('attend', 'attract'): 1 times
# ('attract', 'av'): 1 times
# ('av', 'avail'): 1 times
# ('avail', 'background'): 1 times
# ('background', 'belong'): 1 times
# ('belong', 'best'): 1 times
# ('best', 'big'): 1 times
# ('big', 'body'): 1 times
# ('body', 'branch'): 1 times
# ('branch', 'build'): 1 times
# ('build', 'bye'): 1 times
# ('bye', 'cal'): 1 times
# ('cal', 'camp'): 1 times
# ('camp', 'capston'): 1 times
# ('capston', 'car'): 1 times
# ('car', 'cent'): 1 times
# ('cent', 'choos'): 1 times
# ('choos', 'class'): 1 times
# ('class', 'classroom'): 1 times
# ('classroom', 'cliqu'): 1 times
# ('cliqu', 'club'): 1 times
# ('club', 'co op'): 1 times
# ('co op', 'collab'): 1 times
# ('collab', 'colleg'): 1 times
# ('colleg', 'comfort'): 1 times
# ('comfort', 'commun'): 1 times
# ('commun', 'complaint'): 1 times
# ('complaint', 'complex'): 1 times
# ('complex', 'comput'): 1 times
# ('comput', 'connect'): 1 times
# ('connect', 'contact'): 1 times
# ('contact', 'coop'): 1 times
# ('coop', 'could'): 1 times
# ('could', 'country'): 1 times
# ('country', 'cours'): 1 times
# ('cours', 'cre'): 1 times
# ('cre', 'criter'): 1 times
# ('criter', 'cross cultural'): 1 times
# ('cross cultural', 'culmin'): 1 times
# ('culmin', 'cult'): 1 times
# ('cult', 'dai'): 1 times
# ('dai', 'day'): 1 times
# ('day', 'decid'): 1 times
# ('decid', 'depart'): 1 times
# ('depart', 'describ'): 1 times
# ('describ', 'desir'): 1 times
# ('desir', 'develop'): 1 times
# ('develop', 'diff'): 1 times
# ('diff', 'din'): 1 times
# ('din', 'discussion based'): 1 times
# ('discussion based', 'divers'): 1 times
# ('divers', 'doe'): 1 times
# ('doe', 'dorm'): 1 times
# ('dorm', 'dormit'): 1 times
# ('dormit', 'easy'): 1 times
# ('easy', 'educ'): 1 times
# ('educ', 'effect'): 1 times
# ('effect', 'els'): 1 times
# ('els', 'embrac'): 1 times
# ('embrac', 'emphas'): 1 times
# ('emphas', 'employ'): 1 times
# ('employ', 'eng'): 1 times
# ('eng', 'enjoy'): 1 times
# ('enjoy', 'enough'): 1 times
# ('enough', 'enrol'): 1 times
# ('enrol', 'etc'): 1 times
# ('etc', 'ev'): 1 times
# ('ev', 'ex'): 1 times
# ('ex', 'exclud'): 1 times
# ('exclud', 'expect'): 1 times
# ('expect', 'expery'): 1 times
# ('expery', 'facil'): 1 times
# ('facil', 'facul'): 1 times
# ('facul', 'fair'): 1 times
# ('fair', 'fam'): 1 times
# ('fam', 'favorit'): 1 times
# ('favorit', 'fee'): 1 times
# ('fee', 'fellow'): 1 times
# ('fellow', 'field'): 1 times
# ('field', 'fin'): 1 times
# ('fin', 'find'): 1 times
# ('find', 'first choice'): 1 times
# ('first choice', 'first year'): 1 times
# ('first year', 'food'): 1 times
# ('food', 'form'): 1 times
# ('form', 'fratern'): 1 times
# ('fratern', 'fre'): 1 times
# ('fre', 'freshm'): 1 times
# ('freshm', 'friend'): 1 times
# ('friend', 'gen'): 1 times
# ('gen', 'get'): 1 times
# ('get', 'good'): 1 times
# ('good', 'goodby'): 1 times
# ('goodby', 'gradu'): 1 times
# ('gradu', 'greek'): 1 times
# ('greek', 'group'): 1 times
# ('group', 'guid'): 1 times
# ('guid', 'gym'): 1 times
# ('gym', 'hands on'): 1 times
# ('hands on', 'hang'): 1 times
# ('hang', 'happy'): 1 times
# ('happy', 'hav'): 1 times
# ('hav', 'heavy'): 1 times
# ('heavy', 'hello'): 1 times
# ('hello', 'help'): 1 times
# ('help', 'hey'): 1 times
# ('hey', 'hi'): 1 times
# ('hi', 'high'): 1 times
# ('high', 'hold'): 1 times
# ('hold', 'hometown'): 1 times
# ('hometown', 'hostel'): 1 times
# ('hostel', 'hour'): 1 times
# ('hour', 'hous'): 1 times
# ('hous', 'improv'): 1 times
# ('improv', 'includ'): 1 times
# ('includ', 'independ'): 1 times
# ('independ', 'individ'): 1 times
# ('individ', 'interact'): 1 times
# ('interact', 'intern'): 1 times
# ('intern', 'involv'): 1 times
# ('involv', 'issu'): 1 times
# ('issu', 'job'): 1 times
# ('job', 'kind'): 1 times
# ('kind', 'lab'): 1 times
# ('lab', 'larg'): 1 times
# ('larg', 'lat'): 1 times
# ('lat', 'layout'): 1 times
# ('layout', 'lead'): 1 times
# ('lead', 'learn'): 1 times
# ('learn', 'lecture based'): 1 times
# ('lecture based', 'libr'): 1 times
# ('libr', 'lif'): 1 times
# ('lif', 'lik'): 1 times
# ('lik', 'liv'): 1 times
# ('liv', 'loc'): 1 times
# ('loc', 'lot'): 1 times
# ('lot', 'mad'): 1 times
# ('mad', 'maj'): 1 times
# ('maj', 'mak'): 1 times
# ('mak', 'many'): 1 times
# ('many', 'meet'): 1 times
# ('meet', 'ment'): 1 times
# ('ment', 'modern'): 1 times
# ('modern', 'much'): 1 times
# ('much', 'nam'): 1 times
# ('nam', 'navig'): 1 times
# ('navig', 'near'): 1 times
# ('near', 'nee'): 1 times
# ('nee', 'network'): 1 times
# ('network', 'new'): 1 times
# ('new', 'numb'): 1 times
# ('numb', 'oft'): 1 times
# ('oft', 'on campus'): 1 times
# ('on campus', 'one on on'): 1 times
# ('one on on', 'op'): 1 times
# ('op', 'opportun'): 1 times
# ('opportun', 'opt'): 1 times
# ('opt', 'org'): 1 times
# ('org', 'oth'): 1 times
# ('oth', 'outsid'): 1 times
# ('outsid', 'particip'): 1 times
# ('particip', 'peopl'): 1 times
# ('peopl', 'per'): 1 times
# ('per', 'perc'): 1 times
# ('perc', 'plac'): 1 times
# ('plac', 'pop'): 1 times
# ('pop', 'popul'): 1 times
# ('popul', 'posit'): 1 times
# ('posit', 'pot'): 1 times
# ('pot', 'pract'): 1 times
# ('pract', 'prefer'): 1 times
# ('prefer', 'pres'): 1 times
# ('pres', 'prid'): 1 times
# ('prid', 'prim'): 1 times
# ('prim', 'process'): 1 times
# ('process', 'profess'): 1 times
# ('profess', 'program'): 1 times
# ('program', 'project'): 1 times
# ('project', 'promot'): 1 times
# ('promot', 'provid'): 1 times
# ('provid', 'qual'): 1 times
# ('qual', 'quiet'): 1 times
# ('quiet', 'rac'): 1 times
# ('rac', 're'): 1 times
# ('re', 'reach'): 1 times
# ('reach', 'read'): 1 times
# ('read', 'record'): 1 times
# ('record', 'recr'): 1 times
# ('recr', 'recruit'): 1 times
# ('recruit', 'registr'): 1 times
# ('registr', 'rely'): 1 times
# ('rely', 'repres'): 1 times
# ('repres', 'reput'): 1 times
# ('reput', 'requir'): 1 times
# ('requir', 'research'): 1 times
# ('research', 'resourc'): 1 times
# ('resourc', 'routin'): 1 times
# ('routin', 's'): 1 times
# ('s', 'satisfy'): 1 times
# ('satisfy', 'scen'): 1 times
# ('scen', 'school'): 1 times
# ('school', 'sci'): 1 times
# ('sci', 'see'): 1 times
# ('see', 'segreg'): 1 times
# ('segreg', 'select'): 1 times
# ('select', 'semest'): 1 times
# ('semest', 'sens'): 1 times
# ('sens', 'serv'): 1 times
# ('serv', 'set'): 1 times
# ('set', 'short'): 1 times
# ('short', 'show'): 1 times
# ('show', 'sign'): 1 times
# ('sign', 'siz'): 1 times
# ('siz', 'skil'): 1 times
# ('skil', 'smal'): 1 times
# ('smal', 'soc'): 1 times
# ('soc', 'som'): 1 times
# ('som', 'sor'): 1 times
# ('sor', 'sought after'): 1 times
# ('sought after', 'spec'): 1 times
# ('spec', 'spend'): 1 times
# ('spend', 'spirit'): 1 times
# ('spirit', 'sport'): 1 times
# ('sport', 'spot'): 1 times
# ('spot', 'staff'): 1 times
# ('staff', 'stand'): 1 times
# ('stand', 'standout'): 1 times
# ('standout', 'strengths'): 1 times
# ('strengths', 'strong'): 1 times
# ('strong', 'structured'): 1 times
# ('structured', 'stud'): 1 times
# ('stud', 'student friendly'): 1 times
# ('student friendly', 'study'): 1 times
# ('study', 'subject'): 1 times
# ('subject', 'success'): 1 times
# ('success', 'sum'): 1 times
# ('sum', 'support'): 1 times
# ('support', 'tak'): 1 times
# ('tak', 'talk'): 1 times
# ('talk', 'tas'): 1 times
# ('tas', 'taught'): 1 times
# ('taught', 'teach'): 1 times
# ('teach', 'teamwork'): 1 times
# ('teamwork', 'tel'): 1 times
# ('tel', 'telephon'): 1 times
# ('telephon', 'ther'): 1 times
# ('ther', 'thi'): 1 times
# ('thi', 'thing'): 1 times
# ('thing', 'think'): 1 times
# ('think', 'tim'): 1 times
# ('tim', 'tradit'): 1 times
# ('tradit', 'tut'): 1 times
# ('tut', 'typ'): 1 times
# ('typ', 'un'): 1 times
# ('un', 'upcom'): 1 times
# ('upcom', 'us'): 1 times
# ('us', 'vis'): 1 times
# ('vis', 'week'): 1 times
# ('week', 'weekend'): 1 times
# ('weekend', 'well maintained'): 1 times
# ('well maintained', 'well regarded'): 1 times
# ('well regarded', 'wer'): 1 times
# ('wer', 'wher'): 1 times
# ('wher', 'wif'): 1 times
# ('wif', 'wil'): 1 times
# ('wil', 'work'): 1 times
# ('work', 'would'): 1 times
# ('would', 'writ'): 1 times
# ('writ', 'yo'): 1 times

# %%
print("Creating the Data for our Model.....")
training = []
output = []
print("Creating an List (Empty) for Output.....")
output_empty = [0] * len(classes)

print("Creating Traning Set, Bag of Words for our Model....")
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# Out:
# Creating the Data for our Model.....
# Creating an List (Empty) for Output.....
# Creating Traning Set, Bag of Words for our Model....

# %%
print("Shuffling Randomly and Converting into Numpy Array for Faster Processing......")
random.shuffle(training)
training = np.array(training)

print("Creating Training list")
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Building Neural Network for Out Chatbot to be Contextual....")
print("Resetting graph data....")
tf.reset_default_graph()
# Out:
# Shuffling Randomly and Converting into Numpy Array for Faster Processing......
# Creating Training list
# Building Neural Network for Out Chatbot to be Contextual....
# Resetting graph data....

# %%
net = tflearn.input_data(shape=[None, len(train_x[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(train_y[0]), activation='softmax')
net = tflearn.regression(net)
print("Training....")
# Out:
# WARNING:tensorflow:From c:\Users\psund\anaconda3\envs\qwerty\lib\site-packages\tflearn\initializations.py:164: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Training....

# %%
model = tflearn.DNN(net, tensorboard_dir='tflearn_logs')

# %%
print("Here i am using stochiastic Gradient Descent ALgorithm")
model_filename = 'model.tflearn'
print("Training the model...")
# Assuming you have 'train_x' and 'train_y' defined
model.fit(train_x, train_y, n_epoch=1000, batch_size=10, show_metric=True)
print("Saving the trained model...")
model.save(model_filename)
print("Model saved successfully!")
# Out:
# Training Step: 31967  | total loss: 0.05064 | time: 0.074s
# | Adam | epoch: 1321 | loss: 0.05064 - acc: 0.9894 -- iter: 220/223
# Training Step: 31968  | total loss: 0.05364 | time: 0.078s
# | Adam | epoch: 1321 | loss: 0.05364 - acc: 0.9904 -- iter: 223/223
# --
# Saving the trained model...
# INFO:tensorflow:c:\Users\psund\Documents\chatbot intents - Copy\chatbot intents - Copy\model.tflearn is not in all_model_checkpoint_paths. Manually adding it.
# Model saved successfully!

# %%
from sklearn.model_selection import train_test_split

# Assuming you have 'train_x' and 'train_y' defined
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# Assuming you have a fresh model instance created and compiled
# model = ...

print("Training on the train_test_split data...")
model.fit(X_train, y_train, n_epoch=1000, batch_size=10, show_metric=True, validation_set=(X_test, y_test))

print("Saving the trained model...")
model.save(model_filename)
print("Model saved successfully!")
# Out:
# Training Step: 49967  | total loss: 0.03010 | time: 0.083s
# | Adam | epoch: 2321 | loss: 0.03010 - acc: 0.9948 -- iter: 170/178
# Training Step: 49968  | total loss: 0.02821 | time: 1.101s
# | Adam | epoch: 2321 | loss: 0.02821 - acc: 0.9953 | val_loss: 1.40150 - val_acc: 0.8889 -- iter: 178/178
# --
# Saving the trained model...
# INFO:tensorflow:c:\Users\psund\Documents\chatbot intents - Copy\chatbot intents - Copy\model.tflearn is not in all_model_checkpoint_paths. Manually adding it.
# Model saved successfully!

# %%
print("Pickle is also Saved..........")
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
pickle.dump( {'words':words, 'classes':classes, 'train_x':train_x, 'train_y':train_y}, open( "training_data", "wb" ) )
# Out:
# Pickle is also Saved..........

# %%
print("Loading Pickle.....")
data = pickle.load( open( "training_data", "rb" ) )
words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']


with open('intents.json') as json_data:
    intents = json.load(json_data)
    
#print("Loading the Model......")
#model.load("./model.tflearn")
# Out:
# Loading Pickle.....

# %%
def clean_up_sentence(sentence):
    # It Tokenize or Break it into the constituents parts of Sentense.
    sentence_words = nltk.word_tokenize(sentence)
    # Stemming means to find the root of the word.
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# Return the Array of Bag of Words: True or False and 0 or 1 for each word of bag that exists in the Sentence
def bow(sentence, words, show_details=False):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

ERROR_THRESHOLD = 0.8
print("ERROR_THRESHOLD = 0.8")

def classify(sentence):
    # Prediction or To Get the Posibility or Probability from the Model
    results = model.predict([bow(sentence, words)])[0]
    # Exclude those results which are Below Threshold
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # Sorting is Done because heigher Confidence Answer comes first.
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], r[1])) #Tuppl -> Intent and Probability
    return return_list

def response(sentence, userID='123', show_details=False):
    results = classify(sentence)
    # That Means if Classification is Done then Find the Matching Tag.
    if results:
        # Long Loop to get the Result.
        while results:
            for i in intents['intents']:
                # Tag Finding
                if i['tag'] == results[0][0]:
                    # Random Response from High Order Probabilities
                    return print(random.choice(i['responses']))

            results.pop(0)
# Out:
# ERROR_THRESHOLD = 0.8

# %% [markdown]
# # sample GUI for the chatbot

# %%
project = model.load("./model.tflearn")

intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

def clean_up_sentence(sentence):
    # It Tokenize or Break it into the constituents parts of Sentense.
    sentence_words = nltk.word_tokenize(sentence)
    # Stemming means to find the root of the word.
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# Return the Array of Bag of Words: True or False and 0 or 1 for each word of bag that exists in the Sentence
def bow(sentence, words, show_details=False):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

ERROR_THRESHOLD = 0.8
print("ERROR_THRESHOLD = 0.8")

def classify(sentence):
    # Prediction or To Get the Posibility or Probability from the Model
    results = model.predict([bow(sentence, words)])[0]
    # Exclude those results which are Below Threshold
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # Sorting is Done because heigher Confidence Answer comes first.
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], r[1])) #Tuppl -> Intent and Probability
    return return_list

def response(sentence, userID='123', show_details=False):
    results = classify(sentence)
    # That Means if Classification is Done then Find the Matching Tag.
    if results:
        # Long Loop to get the Result.
        while results:
            for i in intents['intents']:
                # Tag Finding
                if i['tag'] == results[0][0]:
                    # Random Response from High Order Probabilities
                    return random.choice(i['responses'])

            results.pop(0)           
            
#Creating GUI with tkinter
import tkinter
from tkinter import *

def send(event=None):
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    
    if msg == 'quit':
        base.destroy()  # exit the program if the user entered "quit"
    elif msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#333333", font=("Arial", 14))
    
        res = response(msg)
        if res is not None:
            ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Chatbot")
base.geometry("1300x575")
base.configure(bg="#444444")
base.resizable(width=False, height=False)

#Create Chat window
ChatLog = Text(base, bd=0, bg="#ffffff", height="10", width="60", font=("Arial", 14),)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="hand2")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Arial",16), text="Send", width="10", height=3,
                    bd=0, bg="#0080ff", activebackground="#0059b3",fg='#ffffff',
                    command=send)

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="#ffffff", width="40", height="4", font=("Arial", 14))
EntryBox.bind("<Return>", send)  # bind the "Enter" key to the send function

#Place all components on the screen
ChatLog.place(x=20,y=20, height=420, width=1250)
scrollbar.place(x=1250, y=20, height=420)
EntryBox.place(x=20, y=460, height=100, width=1100)
SendButton.place(x=1149, y=457, height=100)

base.mainloop()
# Out:
# INFO:tensorflow:Restoring parameters from c:\Users\psund\Documents\chatbot intents - Copy\chatbot intents - Copy\model.tflearn
# ERROR_THRESHOLD = 0.8

# %%
import speech_recognition as sr
import pyttsx3

def speak(text):
    # Initialize the text-to-speech engine
    engine = pyttsx3.init()
    engine.say(text)
    engine.runAndWait()

# Initialize the recognizer
recognizer = sr.Recognizer()

# Use the microphone as the audio source
with sr.Microphone() as source:
    print("Say something:")
    # Adjust for ambient noise
    recognizer.adjust_for_ambient_noise(source)
    
    # Listen to the audio input
    audio = recognizer.listen(source)

    print("Recognizing...")

    try:
        # Use the Google Web Speech API to convert speech to text
        text = recognizer.recognize_google(audio)
        print(f"Text: {text}")
        speak(text)

    except sr.UnknownValueError:
        print("Google Web Speech API could not understand the audio.")

    except sr.RequestError as e:
        print(f"Could not request results from Google Web Speech API; {e}")
# Out:
# Say something:
# Recognizing...
# Text: hello welcome to any AC
